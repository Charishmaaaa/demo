# %% [markdown]
# <a href="https://colab.research.google.com/github/Charishmaaaa/demo/blob/main/Assignment7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.constraints import MaxNorm
from keras.optimizers import SGD
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.utils import to_categorical


seed = 7
numpy.random.seed(seed)


(X_train, y_train), (X_test, y_test) = cifar10.load_data()


X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train = X_train / 255.0
X_test = X_test / 255.0


y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
num_classes = y_test.shape[1]

model = Sequential()


model.add(Conv2D(32, (3, 3), input_shape=(32, 32, 3), padding='same', activation='relu', kernel_constraint=MaxNorm(3)))

model.add(Dropout(0.2))


model.add(Conv2D(32, (3, 3), activation='relu', padding='same', kernel_constraint=MaxNorm(3)))

model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same', kernel_constraint=MaxNorm(3)))


model.add(Dropout(0.2))


model.add(Conv2D(64, (3, 3), activation='relu', padding='same', kernel_constraint=MaxNorm(3)))


model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same', kernel_constraint=MaxNorm(3)))


model.add(Dropout(0.2))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same', kernel_constraint=MaxNorm(3)))


model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dropout(0.2))

model.add(Dense(1024, activation='relu', kernel_constraint=MaxNorm(3)))

model.add(Dropout(0.2))

model.add(Dense(512, activation='relu', kernel_constraint=MaxNorm(3)))

model.add(Dropout(0.2))

model.add(Dense(num_classes, activation='softmax'))

epochs = 25
lrate = 0.01
decay = lrate / epochs
sgd = SGD(learning_rate=lrate, momentum=0.9, nesterov=False)

model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

print(model.summary())


model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=32)
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1] * 100))
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_27 (Conv2D)          (None, 32, 32, 32)        896
#
#  dropout_26 (Dropout)        (None, 32, 32, 32)        0
#
#  conv2d_28 (Conv2D)          (None, 32, 32, 32)        9248
#
#  max_pooling2d_13 (MaxPooli  (None, 16, 16, 32)        0
#  ng2D)
#
#  conv2d_29 (Conv2D)          (None, 16, 16, 64)        18496
#
#  dropout_27 (Dropout)        (None, 16, 16, 64)        0
#
#  conv2d_30 (Conv2D)          (None, 16, 16, 64)        36928
#
#  max_pooling2d_14 (MaxPooli  (None, 8, 8, 64)          0
#  ng2D)
#
#  conv2d_31 (Conv2D)          (None, 8, 8, 128)         73856
#
#  dropout_28 (Dropout)        (None, 8, 8, 128)         0
#
#  conv2d_32 (Conv2D)          (None, 8, 8, 128)         147584
#
#  max_pooling2d_15 (MaxPooli  (None, 4, 4, 128)         0
#  ng2D)
#
#  flatten_4 (Flatten)         (None, 2048)              0
#
#  dropout_29 (Dropout)        (None, 2048)              0
#
#  dense_12 (Dense)            (None, 1024)              2098176
#
#  dropout_30 (Dropout)        (None, 1024)              0
#
#  dense_13 (Dense)            (None, 512)               524800
#
#  dropout_31 (Dropout)        (None, 512)               0
#
#  dense_14 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 2915114 (11.12 MB)
# Trainable params: 2915114 (11.12 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/25
# 1563/1563 [==============================] - 303s 193ms/step - loss: 1.8344 - accuracy: 0.3182 - val_loss: 1.6090 - val_accuracy: 0.3989
# Epoch 2/25
# 1563/1563 [==============================] - 283s 181ms/step - loss: 1.4193 - accuracy: 0.4808 - val_loss: 1.4005 - val_accuracy: 0.4857
# Epoch 3/25
# 1563/1563 [==============================] - 278s 178ms/step - loss: 1.2253 - accuracy: 0.5621 - val_loss: 1.1999 - val_accuracy: 0.5697
# Epoch 4/25
# 1563/1563 [==============================] - 280s 179ms/step - loss: 1.0772 - accuracy: 0.6155 - val_loss: 1.0180 - val_accuracy: 0.6398
# Epoch 5/25
# 1563/1563 [==============================] - 283s 181ms/step - loss: 0.9626 - accuracy: 0.6600 - val_loss: 0.9484 - val_accuracy: 0.6717
# Epoch 6/25
# 1563/1563 [==============================] - 280s 179ms/step - loss: 0.8746 - accuracy: 0.6910 - val_loss: 0.8590 - val_accuracy: 0.7027
# Epoch 7/25
# 1563/1563 [==============================] - 278s 178ms/step - loss: 0.8106 - accuracy: 0.7169 - val_loss: 0.8318 - val_accuracy: 0.7113
# Epoch 8/25
# 1563/1563 [==============================] - 275s 176ms/step - loss: 0.7553 - accuracy: 0.7348 - val_loss: 0.8305 - val_accuracy: 0.7169
# Epoch 9/25
# 1563/1563 [==============================] - 282s 180ms/step - loss: 0.7034 - accuracy: 0.7533 - val_loss: 0.7565 - val_accuracy: 0.7452
# Epoch 10/25
# 1563/1563 [==============================] - 280s 179ms/step - loss: 0.6691 - accuracy: 0.7642 - val_loss: 0.7105 - val_accuracy: 0.7579
# Epoch 11/25
# 1563/1563 [==============================] - 280s 179ms/step - loss: 0.6426 - accuracy: 0.7752 - val_loss: 0.7397 - val_accuracy: 0.7461
# Epoch 12/25
# 1563/1563 [==============================] - 285s 182ms/step - loss: 0.6146 - accuracy: 0.7843 - val_loss: 0.7256 - val_accuracy: 0.7580
# Epoch 13/25
# 1563/1563 [==============================] - 285s 182ms/step - loss: 0.6042 - accuracy: 0.7895 - val_loss: 0.7720 - val_accuracy: 0.7446
# Epoch 14/25
# 1563/1563 [==============================] - 283s 181ms/step - loss: 0.5826 - accuracy: 0.7958 - val_loss: 0.7308 - val_accuracy: 0.7508
# Epoch 15/25
# 1563/1563 [==============================] - 285s 182ms/step - loss: 0.5687 - accuracy: 0.8014 - val_loss: 0.7301 - val_accuracy: 0.7495
# Epoch 16/25
# 1563/1563 [==============================] - 284s 182ms/step - loss: 0.5594 - accuracy: 0.8056 - val_loss: 0.7699 - val_accuracy: 0.7455
# Epoch 17/25
# 1563/1563 [==============================] - 293s 188ms/step - loss: 0.5620 - accuracy: 0.8060 - val_loss: 0.7164 - val_accuracy: 0.7567
# Epoch 18/25
# 1563/1563 [==============================] - 284s 182ms/step - loss: 0.5405 - accuracy: 0.8109 - val_loss: 0.6914 - val_accuracy: 0.7720
# Epoch 19/25
# 1563/1563 [==============================] - 284s 182ms/step - loss: 0.5415 - accuracy: 0.8128 - val_loss: 0.7316 - val_accuracy: 0.7582
# Epoch 20/25
# 1563/1563 [==============================] - 293s 188ms/step - loss: 0.5346 - accuracy: 0.8150 - val_loss: 0.7380 - val_accuracy: 0.7498
# Epoch 21/25
# 1563/1563 [==============================] - 284s 182ms/step - loss: 0.5270 - accuracy: 0.8212 - val_loss: 0.7180 - val_accuracy: 0.7676
# Epoch 22/25
# 1563/1563 [==============================] - 284s 182ms/step - loss: 0.5327 - accuracy: 0.8180 - val_loss: 0.7937 - val_accuracy: 0.7351
# Epoch 23/25
# 1563/1563 [==============================] - 282s 180ms/step - loss: 0.5436 - accuracy: 0.8161 - val_loss: 0.7589 - val_accuracy: 0.7452
# Epoch 24/25
# 1563/1563 [==============================] - 290s 186ms/step - loss: 0.5446 - accuracy: 0.8157 - val_loss: 0.7350 - val_accuracy: 0.7582
# Epoch 25/25
# 1563/1563 [==============================] - 285s 182ms/step - loss: 0.5570 - accuracy: 0.8092 - val_loss: 0.8070 - val_accuracy: 0.7383
# Accuracy: 73.83%

# %%
import numpy as np

# Predict the first 4 images
predictions = model.predict(X_test[:4])

# Convert predictions to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Get the actual labels
actual_labels = np.argmax(y_test[:4], axis=1)

# Compare predicted labels with actual labels
for i in range(4):
    print(f"Predicted: {predicted_labels[i]}, Actual: {actual_labels[i]}")
# Out:
# 1/1 [==============================] - 0s 141ms/step
# Predicted: 3, Actual: 3
# Predicted: 8, Actual: 8
# Predicted: 8, Actual: 8
# Predicted: 0, Actual: 0

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=32)

# Plot the training and validation loss
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Loss')

# Plot the training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Accuracy')
plt.show()
# Out:
# Epoch 1/25
#  495/1563 [========>.....................] - ETA: 3:18 - loss: 0.5480 - accuracy: 0.8176
